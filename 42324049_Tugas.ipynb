# %%
import numpy as np

# %%
# Nomor 1: Matriks 5x5 dengan nilai random
# Membuat matriks 5x5 berisikan angka random (1 - 100)
matriks = np.random.randint(1, 100, size=(5, 5))

print("Matriks 5x5:")
print(matriks)
print("Nilai Maksimum :", np.max(matriks))
print("Nilai Minimum  :", np.min(matriks))
print("Nilai Rata-rata:", np.mean(matriks))
# Out:
# Matriks 5x5:
# [[82 88 22 87 89]
#  [10 65 99 34 27]
#  [32  4 67 98 65]
#  [33  6 83 30  8]
#  [81 99  5 67  1]]
# Nilai Maksimum : 99
# Nilai Minimum  : 1
# Nilai Rata-rata: 51.28

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Nomor 2: Grafik 2 Dimensi (Implicit Curve)
# x^6 + 3*x^4*y^2 - 3*x^4 + 3*x^2*y^4 - x^2*y^3 - 6*x^2*y^2 + 3*x^2 + y^6 - 3*y^4 + 3*y^2 = 1

x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)

# Persamaan implisit diubah menjadi bentuk F(x, y) = 0
F2D = (X**6 + 3*X**4*Y**2 - 3*X**4 + 3*X**2*Y**4 - X**2*Y**3 
       - 6*X**2*Y**2 + 3*X**2 + Y**6 - 3*Y**4 + 3*Y**2 - 1)

plt.figure(figsize=(6, 6))
plt.contour(X, Y, F2D, levels=[0], colors='red')
plt.title('Grafik 2D Persamaan Implisit')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %%
# Nomor 3: Grafik 3 Dimensi
# z = (5*y/4 - |x|)^2 + x^2

x = np.linspace(-3, 3, 200)
y = np.linspace(-3, 3, 200)
X, Y = np.meshgrid(x, y)

Z = (5 * Y / 4 - np.abs(X))**2 + X**2

fig = plt.figure(figsize=(8, 6))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

ax.set_title('Grafik 3D')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()
